# %% [markdown]
# # Exploratory data analysis / Analyse Exploratoire de données

# %%
# build and tested with python 3.11.0
import pandas as pd

# %%
SOURCE = '../sources/train.csv'

# make sure we can open file... 
df = pd.read_csv(SOURCE)
display(df.sample(10))
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 1420    1421  CA-2016-124800  26/09/2016  30/09/2016  Standard Class
# 7676    7677  CA-2015-142951  08/10/2015  08/10/2015        Same Day
# 1631    1632  CA-2017-106530  08/05/2017  08/05/2017        Same Day
# 210      211  CA-2018-135860  01/12/2018  07/12/2018  Standard Class
# 4472    4473  CA-2018-121300  29/09/2018  29/09/2018        Same Day
# 7603    7604  CA-2017-152520  08/07/2017  12/07/2017  Standard Class
# 735      736  CA-2018-131954  21/01/2018  25/01/2018  Standard Class
# 955      956  CA-2018-119305  30/11/2018  04/12/2018  Standard Class
# 4236    4237  CA-2017-162404  23/07/2017  27/07/2017  Standard Class
# 4204    4205  CA-2015-145387  31/10/2015  02/11/2015    Second Class
#
#      Customer ID      Customer Name      Segment        Country        City  \
# 1420    RW-19540        Rick Wilson    Corporate  United States        Mesa
# ...

# %%
# check what fields we have and how many rows/columns
print(f'Number of rows: {df.shape[0]}')
print(f'Number of columns: {df.shape[1]}')

# note that describe will only show numeric
print(df.describe())
# Out:
# Number of rows: 9800
# Number of columns: 18
#             Row ID   Postal Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %%
df_backup = df.copy()
# if we break something we can always go df = df_backup.copy()

# %%
df = df.iloc[:,1:]
display(df)
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1     CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2     CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3     US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4     US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# ...              ...         ...         ...             ...         ...
# 9795  CA-2017-125920  21/05/2017  28/05/2017  Standard Class    SH-19975
# 9796  CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
#
#          Customer Name    Segment        Country             City       State  \
# ...
